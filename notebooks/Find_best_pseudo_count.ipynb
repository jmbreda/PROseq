# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bin_size = 1000

#infile_proseq = f'../results/GRCm38/binned_norm_coverage/expression_tables/bin_expression_table_bin{bin_size}bp.csv'
infile_rnaseq = f'~/RNAseq/results/Koike_Science_2012/star/binned_norm_coverage/UniqueMultiple_rpm/expression_tables/bin_expression_table_bin{bin_size}bp.csv'

samples = ['']
# read data
#proseq = pd.read_csv(infile_proseq, sep='\t')
#proseq.loc[:,samples] /= bin_size
#proseq.drop('strand', axis=1, inplace=True)
rnaseq = pd.read_csv(infile_rnaseq, sep='\t')
# flip strands of rnaseq
#rnaseq.columns = [col[:-1] + ('+' if col[-1]=='-' else '-') for col in rnaseq.columns]
#rnaseq.columns = proseq.columns
#rnaseq.loc[:,samples] /= bin_size

# %%
rnaseq
# Out:
#           chr    start      end        CT00+        CT04+        CT08+  \
# 0        chr1  3000000  3001000          NaN          NaN          NaN
# 1        chr1  3004000  3005000          NaN          NaN          NaN
# 2        chr1  3008000  3009000          NaN          NaN          NaN
# 3        chr1  3015000  3016000      0.04576          NaN          NaN
# 4        chr1  3016000  3017000          NaN      0.04323          NaN
# ...       ...      ...      ...          ...          ...          ...
# 1245797  chrM    12000    13000   3862.23062   5389.36526   9063.40541
# 1245798  chrM    13000    14000   1717.56378   2608.13625   5603.32978
# 1245799  chrM    14000    15000  11528.62218  13230.76966  21194.99402
# 1245800  chrM    15000    16000  18936.33211  18563.89847  17892.42578
# 1245801  chrM    16000    16299    431.45008    343.36146    188.19144
#
#                CT12+        CT16+        CT20+        CT24+  ...        CT08-  \
# 0                NaN          NaN          NaN          NaN  ...          NaN
# 1                NaN          NaN          NaN          NaN  ...          NaN
# 2                NaN          NaN      0.06108          NaN  ...          NaN
# 3                NaN          NaN          NaN          NaN  ...          NaN
# 4                NaN          NaN          NaN          NaN  ...          NaN
# ...              ...          ...          ...          ...  ...          ...
# 1245797  10355.17216   9846.92564  12427.49378   9176.11160  ...   1263.77453
# 1245798   6162.27388   5597.94988   9173.22355   7571.55213  ...   2829.27536
# 1245799  26570.77422  25136.95537  33866.38636  26563.89031  ...  36924.41650
# 1245800  21658.42587  19408.18045  20796.47989  26972.25297  ...   4911.57007
# 1245801    316.48176    249.64043    294.07608    666.94208  ...   2231.49591
#
#                CT12-        CT16-        CT20-        CT24-        CT28-  \
# 0                NaN          NaN          NaN          NaN          NaN
# 1                NaN          NaN          NaN          NaN          NaN
# 2                NaN          NaN          NaN          NaN          NaN
# 3                NaN          NaN          NaN          NaN          NaN
# 4                NaN          NaN          NaN          NaN          NaN
# ...              ...          ...          ...          ...          ...
# 1245797   1326.83104   1946.16272   2040.29939   1237.55108   1341.23641
# 1245798   3102.26371   3576.63840   3987.54148   4087.55725   3564.20358
# 1245799  35350.90291  37647.72496  32592.63722  31183.23079  29780.52444
# 1245800   5924.53616   6441.80268   4481.42467   5840.15848   5545.54117
# 1245801   2343.02066   3071.69740   2738.06184   1999.42806   1756.61478
#
#                CT32-        CT36-        CT40-        CT44-
# 0                NaN          NaN          NaN          NaN
# 1                NaN          NaN          NaN          NaN
# 2                NaN          NaN          NaN          NaN
# 3                NaN          NaN          NaN          NaN
# 4                NaN          NaN          NaN          NaN
# ...              ...          ...          ...          ...
# 1245797   1178.78677   1652.79256   1077.64538   1180.75896
# 1245798   3303.50426   3303.07170   3232.77570   4252.30558
# 1245799  32978.74915  28228.11232  36891.98052  27638.37694
# 1245800   9847.61076   8805.92156   7214.88104   7617.07566
# 1245801   1630.74004   2253.30793   1892.19489   1977.47013
#
# [1245802 rows x 27 columns]
