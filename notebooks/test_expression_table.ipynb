# %%
import pandas as pd
import numpy as np
import os

# %%
bedfiles = ['results/GRCm38/binned_norm_coverage/CT00/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT04/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT08/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT12/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT16/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT20/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT24/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT28/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT32/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT36/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT40/NormCoverage_3p_forward_bin1000bp.bedgraph','results/GRCm38/binned_norm_coverage/CT44/NormCoverage_3p_forward_bin1000bp.bedgraph']

# %%
np.unique( np.array([b.split('/')[-1].split('_')[2] for b in bedfiles]) )[0]
# Out:
# 'forward'

# %%
time_points = np.array([b.split('/')[-2] for b in bedfiles])

# %%
infile = '../results/GRCm38/binned_norm_coverage/bin_expression_table_chr19_forward_bin1000bp.csv'
df = pd.read_csv(infile, sep ='\t')

# %%
df
# Out:
#           start       end       CT00        CT04        CT08        CT12  \
# 0       3079000   3080000        NaN         NaN         NaN         NaN
# 1       3080000   3081000        NaN         NaN         NaN         NaN
# 2       3083000   3084000  191.47041  109.265745  178.499680  149.656859
# 3       3084000   3085000   34.92228   37.878737   40.658285   43.801982
# 4       3085000   3086000   45.76022   24.038459   13.883305   54.752480
# ...         ...       ...        ...         ...         ...         ...
# 25567  61280000  61281000        NaN         NaN         NaN         NaN
# 25568  61283000  61284000        NaN         NaN         NaN         NaN
# 25569  61302000  61303000        NaN         NaN         NaN         NaN
# 25570  61312000  61313000        NaN         NaN         NaN         NaN
# 25571  61321000  61322000        NaN         NaN    0.991665         NaN
#
#             CT16       CT20        CT24        CT28        CT32        CT36  \
# ...
